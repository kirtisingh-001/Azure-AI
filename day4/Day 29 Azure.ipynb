# %%
from openai import OpenAI

endpoint = "https://kirti22scse1012550668-resource.openai.azure.com/openai/v1/"
deployment_name = "gpt-4.1"
api_key = "7uj5M9C6nIdhCo2lPfNPJQsIhNnLVs8LZNubWuxbjgCQvTcP1SHpJQQJ99CDACNns7RXJ3w3AAAAACOGLEDE"

client = OpenAI(
    base_url=endpoint,
    api_key=api_key
)

completion = client.chat.completions.create(
    model=deployment_name,
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?",
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='The capital of France is **Paris**.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None)

# %%
from google.colab import userdata

# %%
from google.colab import userdata
from openai import OpenAI

# Fetch API key (your saved name)
api_key = userdata.get("ghjk")

# Azure OpenAI config
endpoint = "https://kirti22scse1012550668-resource.openai.azure.com/"
deployment_name = "gpt-4.1"

# Create client
client = OpenAI(
    api_key=api_key,
    base_url=f"{endpoint}openai/deployments/{deployment_name}",
    default_query={"api-version": "2024-02-01"},
)

# Request
response = client.chat.completions.create(
    model=deployment_name,
    messages=[
        {"role": "user", "content": "Who is the prime minister of France?"}
    ],
)

# Output
print(response.choices[0].message.content)
# Out:
# As of June 2024, the Prime Minister of France is **Gabriel Attal**. He was appointed to the position in January 2024.
